# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihan-49/Python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (a) Declare variables and print their types

name = "John"
age = 20
gpa = 3.75
is_student = True

print(type(name))
print(type(age))
print(type(gpa))
print(type(is_student))


# (b) Type conversions

# String to integer
num_str = "123"
print(int(num_str))

# Integer to string
num_int = 456
print(str(num_int))

# Float to integer
float_num = 3.99
print(int(float_num))
# The decimal part (.99) is removed (not rounded)

# Integers to boolean
print(bool(1))  # True
print(bool(0))  # False

# %%
a = 17
b = 5

# Arithmetic operations
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)

# Floor division and modulus
print("Floor Division:", a // b)
print("Modulus:", a % b)

# Power
print("17 raised to power 5:", a ** b)

# Comparisons
print("17 > 5:", a > b)
print("17 == 5:", a == b)
print("17 != 5:", a != b)

# %%
# (a)
name = "python programming"

print(name.upper())
print(name.title())
print(name.replace("programming", "language"))
print(len(name))


# (b) f-string
my_name = "John"
my_age = 20
my_gpa = 3.75

print(f"My name is {my_name}, I am {my_age} years old, and my GPA is {my_gpa}")

# %%
age = int(input("Enter your age: "))

if age < 0:
    print("Invalid age")
elif age > 18:
    print("You are an adult")
elif 13 <= age <= 17:
    print("You are a teenager")
else:
    print("You are a child")

# %%
num = int(input("Enter a number: "))
print("Even" if num % 2 == 0 else "Odd")

# %%
mark = int(input("Enter your mark (0-100): "))

if mark < 0 or mark > 100:
    print("Invalid mark")
elif mark >= 90:
    print("A+")
elif mark >= 80:
    print("A")
elif mark >= 70:
    print("B")
elif mark >= 60:
    print("C")
elif mark >= 50:
    print("D")
else:
    print("F — Failed")

# %%
correct_username = "admin"
correct_password = "1234"

attempts = 3

while attempts > 0:
    username = input("Enter username: ")
    password = input("Enter password: ")

    if username == correct_username and password == correct_password:
        print(f"Login successful! Welcome, {username}.")
        break
    elif username == correct_username:
        print("Incorrect password. Try again.")
    else:
        print("User not found.")

    attempts -= 1
    print("Attempts remaining:", attempts)

if attempts == 0:
    print("Account locked.")

# %%
pinNumber = "1234"
balance = 5000

entered_pin = input("Enter your PIN: ")

if entered_pin == pinNumber:
    request = int(input("Enter withdrawal amount: "))

    if request > balance:
        print("Insufficient balance.")
    elif request <= 500:
        print("Minimum withdrawal amount is greater than 500.")
    else:
        balance -= request
        print("Withdrawal successful.")
        print("Remaining balance:", balance)
else:
    print("Wrong PIN.")

# %%
pinNumber = "1234"
balance = 5000
attempts = 3

while attempts > 0:
    entered_pin = input("Enter your PIN: ")

    if entered_pin == pinNumber:
        print("PIN correct.")
        break
    else:
        attempts -= 1
        print(f"Wrong pin. Attempts remaining: {attempts}")

if attempts == 0:
    print("Card blocked!")

# %%
username = "admin"
password = "1234"
is_active = True

user_input = input("Enter username: ")
pass_input = input("Enter password: ")

if not is_active:
    print("Account is disabled.")
elif user_input == username and pass_input == password:
    print("Login successful!")
    # Proceed to ATM section
else:
    print("Invalid login credentials.")

# %%
# 1 to 20
for i in range(1, 21):
    print(i)

# Multiplication table of 7
for i in range(1, 11):
    print(f"7 x {i} = {7*i}")

# Sum 1 to 100
total = 0
for i in range(1, 101):
    total += i
print("Sum:", total)

# Even numbers 1 to 50
for i in range(2, 51, 2):
    print(i)

# Fruits with position
fruits = ['apple', 'banana', 'cherry', 'mango', 'grape']

for index, fruit in enumerate(fruits, start=1):
    print(index, fruit)

# %%
# 10 down to 1
num = 10
while num >= 1:
    print(num)
    num -= 1


# Sum until user enters 0 or negative
total = 0
while True:
    number = int(input("Enter a positive number: "))
    if number <= 0:
        break
    total += number
print("Total sum:", total)


# Countdown
count = 10
while count >= 0:
    print(count)
    count -= 1
print("Blast off!")


# First 10 multiples of 6
count = 1
while count <= 10:
    print(6 * count)
    count += 1
